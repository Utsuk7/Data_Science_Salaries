# %% [markdown]
# <a href="https://colab.research.google.com/github/Utsuk7/Data_Science_Salaries/blob/main/Data_Science_Salaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/content/ds_salaries.csv")

# %%
data.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# 1               US            S
# 2               US            S
# 3               CA            M
# 4               CA            M

# %%
data['experience_level'].value_counts()
# Out:
# SE    2516
# MI     805
# EN     320
# EX     114
# Name: experience_level, dtype: int64

# %%
data.drop(columns=["salary","salary_currency"],inplace=True)

# %%
data.shape
# Out:
# (3755, 9)

# %%
salary=[]
year=[]
for i in range(2020,2024):
    salary.append(data[data["work_year"]==i]["salary_in_usd"].mean())
    year.append(i)
plt.title("Salary Trends based on Year")
plt.bar(year,salary,linewidth=2,width=1,edgecolor="white")
plt.legend("salary")
plt.show()

# %%
data[data["job_title"]=="Data Engineer"]["salary_in_usd"].mean()
job=data["job_title"].value_counts().head(20)
job_title=[]
mean_job_salary=[]
for i in job.index:
    job_title.append(i)
    mean_job_salary.append(data[data["job_title"]==i]["salary_in_usd"].mean())

plt.title("Top - 20 Role vs Salary")
plt.barh(job_title,mean_job_salary,)
plt.figure(figsize=(20,20))
plt.show()

# %%
data["experience_level"].value_counts().index
exp_index=[]
exp_sal=[]
for i in data["experience_level"].value_counts().index:
    exp_index.append(i)
    exp_sal.append(data[data["experience_level"]==i]["salary_in_usd"].mean())
for i, v in enumerate(exp_sal):
    plt.text(i, v + 0.5, str(v), ha='center')
plt.xlabel("SE - SENIOR || MI - MID LEVEL || EN - ENTRY LEVEL || EX - EXPERT")
plt.bar(exp_index,exp_sal)
plt.ylabel("Avg salary for a data science role")
plt.figure(figsize=(20,10))

plt.show()

# %%
loc=data["company_location"].value_counts().head(10)
con=[]
con_sal=[]
for i in loc.index:
    con.append(i)
    con_sal.append(data[data["company_location"]==i]["salary_in_usd"].mean())
plt.bar(con,con_sal)
plt.xlabel("country")
plt.ylabel("avg salary for a data science role")
plt.show()

# %%
data["work_type"]=data["remote_ratio"].replace({0:"in-office",100:"fully remote",50:"hybrid"})

# %%
work_type=[]
work_sal=[]
for i in data["work_type"].value_counts().index:
    work_type.append(i)
    work_sal.append(data[data["work_type"]==i]["salary_in_usd"].mean())
plt.bar(work_type,work_sal)
plt.title("Work-type vs Salary")
plt.xlabel("work-type")
plt.ylabel("Avg salary for a daat science role")
plt.show()

# %%
data.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary_in_usd employee_residence  remote_ratio company_location  \
# 0          85847                 ES           100               ES
# 1          30000                 US           100               US
# 2          25500                 US           100               US
# 3         175000                 CA           100               CA
# 4         120000                 CA           100               CA
#
#   company_size     work_type
# 0            L  fully remote
# 1            S  fully remote
# 2            S  fully remote
# 3            M  fully remote
# 4            M  fully remote

# %%
data.drop(["employee_residence"],axis=1,inplace=True)

# %%
data
# Out:
#       work_year experience_level employment_type  \
# 0          2023               SE              FT
# 1          2023               MI              CT
# 2          2023               MI              CT
# 3          2023               SE              FT
# 4          2023               SE              FT
# 5          2023               SE              FT
# 6          2023               SE              FT
# 7          2023               SE              FT
# 8          2023               SE              FT
# 9          2023               SE              FT
# 10         2023               SE              FT
# 11         2023               SE              FT
# 473        2023               EX              FT
# 474        2023               SE              FT
# 475        2023               SE              FT
# 476        2023               SE              FT
# 477        2023               SE              FT
# 478        2023               EX              FT
# 479        2023               EX              FT
# 480        2023               MI              FT
# 481        2023               MI              FT
# 482        2023               SE              FT
# 483        2023               SE              FT
# 484        2023               MI              FT
# 485        2023               MI              FT
# 486        2023               SE              FT
# 487        2023               SE              FT
# 488        2023               SE              FT
# 489        2023               SE              FT
# 490        2023               SE              FT
# 491        2023               SE              FT
# 492        2023               EN              FT
# 493        2023               SE              FT
# 494        2023               SE              FT
# 495        2023               MI              FT
# 496        2023               MI              FT
# 497        2023               SE              FT
# 498        2023               SE              FT
# 499        2023               SE              FT
# 500        2023               SE              FT
# 501        2023               SE              FT
# 502        2023               SE              FT
# 503        2023               SE              FT
# 504        2023               SE              FT
# 505        2023               SE              FT
# 506        2023               SE              FT
# 507        2023               SE              FT
# 508        2023               SE              FT
# 509        2023               SE              FT
# 510        2023               SE              FT
# 511        2023               SE              FT
# 512        2023               SE              FT
# 513        2023               SE              FT
# 514        2023               SE              FT
# 515        2023               EN              FT
# 516        2023               EN              FT
# 517        2023               SE              FT
# 518        2023               SE              FT
# 519        2023               SE              FT
# 520        2023               SE              FT
# 521        2023               SE              FT
# 522        2023               SE              FT
# 523        2023               MI              FT
# 524        2023               MI              FT
# 525        2023               SE              FT
# 526        2023               SE              FT
# 527        2023               MI              FT
# 528        2023               SE              FT
# 529        2023               SE              FT
# 530        2023               SE              FT
# 531        2023               SE              FT
# 532        2023               SE              FT
# 533        2023               SE              FT
# 534        2023               SE              FT
# 535        2023               SE              FT
# 536        2023               SE              FT
# 537        2023               MI              FT
# 538        2023               MI              FT
# 539        2023               MI              FT
# 540        2023               MI              FT
# 541        2023               SE              FT
# 542        2023               SE              FT
# 543        2023               SE              FT
# 544        2023               SE              FT
# 545        2023               SE              FT
# 546        2023               SE              FT
# 547        2023               SE              FT
# 548        2023               SE              FT
# 549        2023               SE              FT
# 550        2023               SE              FT
# 551        2023               MI              FT
# 552        2023               MI              FT
# 553        2023               EX              FT
# 554        2023               EX              FT
# 555        2023               SE              FT
# 556        2023               SE              FT
# 557        2023               SE              FT
# 558        2023               SE              FT
# 559        2023               MI              FT
# 560        2023               MI              FT
# 561        2023               MI              FT
# 562        2023               MI              FT
# 563        2023               MI              FT
# 564        2023               MI              FT
# 565        2023               SE              FT
# 566        2023               SE              FT
# 567        2023               SE              FT
# 568        2023               SE              FT
# 569        2023               SE              FT
# 570        2023               SE              FT
# 571        2023               SE              FT
# 572        2023               SE              FT
# 573        2023               EN              FT
# 574        2023               EN              FT
# 575        2023               SE              FT
# 576        2023               SE              FT
# 577        2023               MI              FT
# 578        2023               MI              FT
# 579        2023               MI              FT
# 580        2023               MI              FT
# 581        2023               EN              FT
# 582        2023               EN              FT
# 583        2023               MI              FT
# 584        2023               MI              FT
# 585        2023               MI              FT
# 586        2023               MI              FT
# 587        2023               SE              FT
# 588        2023               SE              FT
# 704        2023               MI              FT
# 705        2023               MI              FT
# 706        2023               MI              FT
# 707        2023               EX              FT
# 708        2023               EX              FT
# 709        2023               MI              FT
# 710        2023               MI              FT
# 711        2023               SE              FT
# 712        2023               SE              FT
# 713        2023               MI              FT
# 714        2023               SE              FT
# 715        2023               SE              FT
# 716        2023               SE              FT
# 717        2023               SE              FT
# 718        2023               SE              FT
# 719        2023               SE              FT
# 720        2023               SE              FT
# 721        2023               SE              FT
# 722        2023               SE              FT
# 723        2023               SE              FT
# 724        2023               SE              FT
# 725        2023               SE              FT
# 726        2023               MI              FT
# 727        2023               MI              FT
# 728        2023               MI              FT
# 729        2023               MI              FT
# 730        2023               SE              FT
# 731        2023               SE              FT
# 732        2023               MI              FT
# 733        2023               SE              FT
# 734        2023               SE              FT
# 735        2023               MI              FT
# 736        2023               EN              FT
# 737        2023               EN              FT
# 738        2023               MI              FT
# 739        2023               MI              FT
# 740        2023               MI              FT
# 741        2023               SE              FT
# 742        2023               SE              FT
# 743        2023               SE              FT
# 744        2023               SE              FT
# 745        2023               EX              FT
# 746        2023               EX              FT
# 747        2023               EN              FT
# 748        2023               EN              FT
# 749        2023               SE              FT
# 750        2023               SE              FT
# 751        2023               EN              FT
# 752        2023               EN              FT
# 753        2023               MI              FT
# 754        2023               MI              FT
# 755        2023               SE              FT
# 756        2023               SE              FT
# 757        2023               SE              FT
# 758        2023               SE              FT
# 759        2023               SE              FT
# 760        2023               SE              FT
# 761        2023               SE              FT
# 762        2023               SE              FT
# 763        2023               SE              FT
# 764        2023               SE              FT
# 765        2023               MI              FT
# 766        2023               MI              FT
# 767        2023               MI              FT
# 768        2023               MI              FT
# 769        2023               SE              FT
# 770        2023               SE              FT
# 771        2023               SE              FT
# 772        2023               SE              FT
# 773        2023               SE              FT
# 774        2023               SE              FT
# 775        2022               SE              FT
# 776        2021               MI              FT
# 777        2023               SE              FT
# 778        2023               SE              FT
# 779        2023               SE              FT
# 780        2023               SE              FT
# 781        2023               SE              FT
# 782        2023               SE              FT
# 783        2023               SE              FT
# 784        2023               SE              FT
# 785        2023               SE              FT
# 786        2023               SE              FT
# 787        2023               SE              FT
# 788        2023               SE              FT
# 789        2023               MI              FT
# 790        2023               MI              FT
# 791        2023               SE              FT
# 792        2023               SE              FT
# 793        2023               SE              FT
# 794        2023               SE              FT
# 795        2023               MI              FT
# 796        2023               MI              FT
# 797        2023               EX              FT
# 798        2023               EX              FT
# 799        2023               SE              FT
# 800        2023               SE              FT
# 801        2023               SE              FT
# 802        2023               SE              FT
# 803        2023               MI              FT
# 804        2023               MI              FT
# 805        2023               SE              FT
# 806        2023               SE              FT
# 807        2023               SE              FT
# 808        2023               SE              FT
# 809        2023               SE              FT
# 810        2023               MI              FT
# 811        2023               MI              FT
# 812        2023               MI              FT
# 813        2023               MI              FT
# 814        2023               SE              FT
# 815        2023               SE              FT
# 816        2023               EN              FT
# 817        2023               EN              FT
# 818        2023               MI              FT
# 819        2023               MI              FT
# 820        2023               SE              FT
# 821        2023               SE              FT
# 822        2023               SE              FT
# 823        2023               SE              FT
# 824        2023               MI              FT
# 825        2023               MI              FT
# 826        2023               SE              FT
# 827        2023               SE              FT
# 828        2023               SE              FT
# 829        2023               SE              FT
# 830        2023               SE              FT
# 831        2023               SE              FT
# 832        2023               SE              FT
# 833        2023               SE              FT
# 834        2023               SE              FT
# 835        2023               SE              FT
# 836        2023               EN              FT
# 837        2023               MI              FT
# 838        2023               MI              FT
# 839        2023               SE              FT
# 840        2023               SE              FT
# 841        2023               MI              FT
# 842        2023               MI              FT
# 843        2023               SE              FT
# 844        2023               SE              FT
# 845        2023               MI              FT
# 846        2023               MI              FT
# 847        2023               SE              FT
# 848        2023               SE              FT
# 849        2023               MI              FT
# 850        2023               MI              FT
# 851        2023               MI              FT
# 852        2023               SE              FT
# 853        2023               SE              FT
# 854        2023               SE              FT
# 855        2023               SE              FT
# 856        2023               SE              FL
# 857        2023               EN              FT
# 858        2023               SE              FT
# 859        2023               SE              FT
# 860        2023               EX              FT
# 861        2023               EX              FT
# 862        2023               SE              FT
# 863        2023               SE              FT
# 864        2023               EN              FT
# 865        2023               EN              FT
# 866        2023               SE              FT
# 867        2023               SE              FT
# 868        2023               MI              FT
# 869        2023               MI              FT
# 870        2023               SE              FT
# 871        2023               SE              FT
# 872        2023               SE              FT
# 873        2023               SE              FT
# 874        2023               MI              FT
# 875        2023               MI              FT
# 876        2023               MI              FT
# 877        2023               MI              FT
# 878        2023               SE              FT
# 879        2023               SE              FT
# 880        2023               SE              FT
# 881        2023               SE              FT
# 882        2023               SE              FT
# 883        2023               SE              FT
# 884        2023               EN              FT
# 885        2023               EN              FT
# 886        2023               MI              FT
# 887        2023               MI              FT
# 888        2023               MI              FT
# 889        2023               MI              FT
# 890        2023               SE              FT
# 891        2023               SE              FT
# 892        2023               SE              FT
# 893        2023               SE              FT
# 894        2023               SE              FT
# 895        2023               SE              FT
# 896        2023               MI              FT
# 897        2023               MI              FT
# 898        2023               SE              FT
# 899        2023               SE              FT
# 900        2023               MI              FT
# 901        2023               MI              FT
# 902        2023               SE              FT
# 903        2023               SE              FT
# 904        2023               SE              FT
# 905        2023               SE              FT
# 906        2023               SE              FT
# 907        2023               SE              FT
# 908        2023               MI              FT
# 909        2023               MI              FT
# 910        2023               SE              FT
# 911        2023               SE              FT
# 912        2023               MI              FT
# 913        2023               MI              FT
# 914        2023               SE              FT
# 915        2023               SE              FT
# 916        2023               MI              FT
# 917        2023               MI              FT
# 918        2023               SE              FT
# 919        2023               SE              FT
# 920        2023               SE              FT
# 921        2023               SE              FT
# ...
# 3442               AU            L  fully remote
# 3443               MY            L  fully remote
# 3444               EE            S  fully remote
# 3445               NL            L  fully remote
# 3446               DE            L  fully remote
# 3447               FR            L        hybrid
# 3448               AU            M        hybrid
# 3449               US            M  fully remote
# 3450               US            M        hybrid
# 3451               US            M  fully remote
# 3452               CA            M  fully remote
# 3453               PL            L  fully remote
# 3454               CA            S  fully remote
# 3455               HN            S     in-office
# 3456               CZ            M  fully remote
# 3457               CZ            L        hybrid
# 3458               DE            M  fully remote
# 3459               AT            L     in-office
# 3460               US            M  fully remote
# 3461               US            L  fully remote
# 3462               US            L  fully remote
# 3463               US            L  fully remote
# 3464               US            L     in-office
# 3465               US            L     in-office
# 3466               US            L  fully remote
# 3467               US            M  fully remote
# 3468               US            L  fully remote
# 3469               CH            L     in-office
# 3470               US            L  fully remote
# 3471               FR            M  fully remote
# 3472               US            S  fully remote
# 3473               PK            M     in-office
# 3474               US            L     in-office
# 3475               JP            S        hybrid
# 3476               JP            S        hybrid
# 3477               AU            S  fully remote
# 3478               US            M  fully remote
# 3479               US            M  fully remote
# 3480               US            S     in-office
# 3481               DZ            M        hybrid
# 3482               US            L        hybrid
# 3483               DE            M  fully remote
# 3484               BR            M  fully remote
# 3485               US            M  fully remote
# 3486               US            L        hybrid
# 3487               US            S  fully remote
# 3488               FR            M        hybrid
# 3489               IN            L        hybrid
# 3490               US            M  fully remote
# 3491               DE            M     in-office
# 3492               IN            S  fully remote
# 3493               US            M     in-office
# 3494               IN            S     in-office
# 3495               US            S        hybrid
# 3496               ES            M        hybrid
# 3497               GB            L     in-office
# 3498               PT            L  fully remote
# 3499               US            M  fully remote
# 3500               US            M  fully remote
# 3501               RO            M        hybrid
# 3502               US            L  fully remote
# 3503               IQ            S        hybrid
# 3504               US            L  fully remote
# 3505               BE            M        hybrid
# 3506               DE            S  fully remote
# 3507               FR            M        hybrid
# 3508               GB            L  fully remote
# 3509               US            L  fully remote
# 3510               US            L  fully remote
# 3511               US            S        hybrid
# 3512               US            L     in-office
# 3513               US            L  fully remote
# 3514               US            L  fully remote
# 3515               DE            M        hybrid
# 3516               DE            L        hybrid
# 3517               US            L  fully remote
# 3518               RU            M     in-office
# 3519               RU            L        hybrid
# 3520               US            S  fully remote
# 3521               US            M  fully remote
# 3522               US            M     in-office
# 3523               FR            L        hybrid
# 3524               AT            L        hybrid
# 3525               CA            L        hybrid
# 3526               US            L  fully remote
# 3527               UA            L  fully remote
# 3528               CA            L  fully remote
# 3529               US            M  fully remote
# 3530               US            L  fully remote
# 3531               US            L  fully remote
# 3532               US            L  fully remote
# 3533               US            S  fully remote
# 3534               US            S  fully remote
# 3535               NG            L  fully remote
# 3536               US            M  fully remote
# 3537               IN            M        hybrid
# 3538               US            L  fully remote
# 3539               CA            L        hybrid
# 3540               ES            S  fully remote
# 3541               PL            L  fully remote
# 3542               PL            L  fully remote
# 3543               US            L  fully remote
# 3544               GB            L        hybrid
# 3545               US            L        hybrid
# 3546               FR            M        hybrid
# 3547               US            S  fully remote
# 3548               NG            S  fully remote
# 3549               US            S  fully remote
# 3550               US            L  fully remote
# 3551               DE            L  fully remote
# 3552               US            L  fully remote
# 3553               US            M  fully remote
# 3554               US            S  fully remote
# 3555               US            M  fully remote
# 3556               FR            L        hybrid
# 3557               US            L  fully remote
# 3558               US            L  fully remote
# 3559               ES            L        hybrid
# 3560               US            L  fully remote
# 3561               DE            S  fully remote
# 3562               PT            M     in-office
# 3563               DK            L  fully remote
# 3564               GB            S  fully remote
# 3565               GB            M  fully remote
# 3566               DE            L        hybrid
# 3567               IN            L  fully remote
# 3568               US            M  fully remote
# 3569               US            S  fully remote
# 3570               CA            L  fully remote
# 3571               GB            L        hybrid
# 3572               US            L  fully remote
# 3573               GB            L        hybrid
# 3574               US            L        hybrid
# 3575               US            L  fully remote
# 3576               DE            S  fully remote
# 3577               US            S  fully remote
# 3578               US            M  fully remote
# 3579               GB            S  fully remote
# 3580               SG            L        hybrid
# 3581               IN            L        hybrid
# 3582               US            L     in-office
# 3583               US            L  fully remote
# 3584               US            S  fully remote
# 3585               US            L  fully remote
# 3586               US            L  fully remote
# 3587               US            L  fully remote
# 3588               US            L  fully remote
# 3589               IN            M  fully remote
# 3590               PT            L        hybrid
# 3591               US            S  fully remote
# 3592               FR            L        hybrid
# 3593               IN            S     in-office
# 3594               MX            S     in-office
# 3595               US            M  fully remote
# 3596               GB            L        hybrid
# 3597               TR            M     in-office
# 3598               FR            L        hybrid
# 3599               GB            L        hybrid
# 3600               US            L  fully remote
# 3601               CA            M        hybrid
# 3602               US            L  fully remote
# 3603               US            L  fully remote
# 3604               CA            L  fully remote
# 3605               IN            M        hybrid
# 3606               NL            L        hybrid
# 3607               AE            L     in-office
# 3608               CA            M  fully remote
# 3609               JP            S     in-office
# 3610               US            S     in-office
# 3611               US            L  fully remote
# 3612               US            L  fully remote
# 3613               GB            M        hybrid
# 3614               US            L  fully remote
# 3615               US            S  fully remote
# 3616               US            L  fully remote
# 3617               DE            L     in-office
# 3618               US            L  fully remote
# 3619               US            L        hybrid
# 3620               NL            L  fully remote
# 3621               CN            L     in-office
# 3622               US            L  fully remote
# 3623               US            L        hybrid
# 3624               TR            L        hybrid
# 3625               ES            L  fully remote
# 3626               US            L        hybrid
# 3627               US            M  fully remote
# 3628               FR            M        hybrid
# 3629               DE            S  fully remote
# 3630               DE            L     in-office
# 3631               US            M  fully remote
# 3632               US            L  fully remote
# 3633               DE            M        hybrid
# 3634               TR            M  fully remote
# 3635               US            M     in-office
# 3636               US            M     in-office
# 3637               US            S        hybrid
# 3638               DE            S  fully remote
# 3639               IN            L     in-office
# 3640               IN            S  fully remote
# 3641               DE            L        hybrid
# 3642               US            S  fully remote
# 3643               DE            L     in-office
# 3644               IN            L  fully remote
# 3645               CA            M  fully remote
# 3646               HU            L        hybrid
# 3647               US            L     in-office
# 3648               DE            M        hybrid
# 3649               US            L        hybrid
# 3650               IN            L  fully remote
# 3651               KE            S  fully remote
# 3652               US            L        hybrid
# 3653               CA            L        hybrid
# 3654               US            L  fully remote
# 3655               US            L  fully remote
# 3656               CO            M        hybrid
# 3657               NZ            S        hybrid
# 3658               FR            S     in-office
# 3659               IN            L     in-office
# 3660               ES            S  fully remote
# 3661               GB            M  fully remote
# 3662               FR            M     in-office
# 3663               US            L  fully remote
# 3664               US            L     in-office
# 3665               DE            L        hybrid
# 3666               IN            L     in-office
# 3667               US            S  fully remote
# 3668               US            S        hybrid
# 3669               CL            L  fully remote
# 3670               US            S  fully remote
# 3671               AT            M        hybrid
# 3672               US            M  fully remote
# 3673               ES            L  fully remote
# 3674               US            L  fully remote
# 3675               US            S  fully remote
# 3676               CA            L  fully remote
# 3677               GB            L        hybrid
# 3678               IN            M     in-office
# 3679               GB            L        hybrid
# 3680               PL            L  fully remote
# 3681               PK            L        hybrid
# 3682               JP            S  fully remote
# 3683               GB            S  fully remote
# 3684               BE            M  fully remote
# 3685               IN            M        hybrid
# 3686               US            M  fully remote
# 3687               DK            S        hybrid
# 3688               DE            L        hybrid
# 3689               IN            L  fully remote
# 3690               GR            L        hybrid
# 3691               US            M     in-office
# 3692               GB            S        hybrid
# 3693               FR            S        hybrid
# 3694               SI            L        hybrid
# 3695               US            L     in-office
# 3696               US            L     in-office
# 3697               US            L  fully remote
# 3698               US            L  fully remote
# 3699               DK            S        hybrid
# 3700               US            L  fully remote
# 3701               US            S  fully remote
# 3702               GR            M  fully remote
# 3703               BR            S     in-office
# 3704               US            M     in-office
# 3705               CH            L     in-office
# 3706               FR            S        hybrid
# 3707               US            L  fully remote
# 3708               DE            S        hybrid
# 3709               DE            L        hybrid
# 3710               IT            S        hybrid
# 3711               US            L  fully remote
# 3712               US            L  fully remote
# 3713               US            L        hybrid
# 3714               CA            S  fully remote
# 3715               GB            L        hybrid
# 3716               PK            M        hybrid
# 3717               GB            S        hybrid
# 3718               JP            S        hybrid
# 3719               FR            L  fully remote
# 3720               MD            S     in-office
# 3721               US            S  fully remote
# 3722               US            L        hybrid
# 3723               BR            M     in-office
# 3724               LU            L  fully remote
# 3725               DE            M  fully remote
# 3726               DE            M  fully remote
# 3727               ES            M  fully remote
# 3728               ES            M  fully remote
# 3729               AS            S  fully remote
# 3730               AT            S     in-office
# 3731               LU            S        hybrid
# 3732               US            L        hybrid
# 3733               US            L  fully remote
# 3734               IN            L  fully remote
# 3735               US            S  fully remote
# 3736               US            L     in-office
# 3737               US            L     in-office
# 3738               US            L     in-office
# 3739               NL            L  fully remote
# 3740               US            M  fully remote
# 3741               US            M  fully remote
# 3742               US            M  fully remote
# 3743               US            M  fully remote
# 3744               HR            S  fully remote
# 3745               JP            S     in-office
# 3746               IL            M  fully remote
# 3747               US            L        hybrid
# 3748               MT            L        hybrid
# 3749               US            L  fully remote
# 3750               US            L  fully remote
# 3751               US            L  fully remote
# 3752               US            S  fully remote
# 3753               US            L  fully remote
# 3754               IN            L        hybrid

# %%
mean=data["salary_in_usd"].mean()

# %%
std=data["salary_in_usd"].std()

# %%
data["salary_in_usd"].max()
# Out:
# 450000

# %%
137570+3*63055
# Out:
# 326735

# %%
data=data[data["salary_in_usd"]>mean-3*std]
data=data[data["salary_in_usd"]<mean+3*std]

# %%
data.shape
# Out:
# (3733, 9)

# %%
data.isnull().sum()
# Out:
# work_year           0
# experience_level    0
# employment_type     0
# job_title           0
# salary_in_usd       0
# remote_ratio        0
# company_location    0
# company_size        0
# work_type           0
# dtype: int64

# %%
data["job_title"].value_counts()
# Out:
# Data Engineer                1040
# Data Scientist                837
# Data Analyst                  610
# others                        491
# Machine Learning Engineer     288
# Analytics Engineer            103
# Data Architect                 99
# Research Scientist             79
# Data Science Manager           58
# Applied Scientist              57
# Research Engineer              37
# ML Engineer                    34
# Name: job_title, dtype: int64

# %%
cat_var=[]
for i in data['job_title']:
  if data['job_title'].value_counts()[i]<30:
    cat_var.append(i)
cat_var

# %%
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)

# %%
for i in cat_var:
  data.replace({i:"others"},inplace=True)

# %%
data['job_title'].value_counts()['others']
# Out:
# 491

# %%
data['job_title'].value_counts()
# Out:
# Data Engineer                1040
# Data Scientist                837
# Data Analyst                  610
# others                        491
# Machine Learning Engineer     288
# Analytics Engineer            103
# Data Architect                 99
# Research Scientist             79
# Data Science Manager           58
# Applied Scientist              57
# Research Engineer              37
# ML Engineer                    34
# Name: job_title, dtype: int64

# %%
df = data
df.head()
# Out:
#    work_year experience_level employment_type       job_title  salary_in_usd  \
# 0       2023               SE              FT          others          85847
# 1       2023               MI              CT     ML Engineer          30000
# 2       2023               MI              CT     ML Engineer          25500
# 3       2023               SE              FT  Data Scientist         175000
# 4       2023               SE              FT  Data Scientist         120000
#
#    remote_ratio company_location company_size     work_type
# 0           100               ES            L  fully remote
# 1           100               US            S  fully remote
# 2           100               US            S  fully remote
# 3           100               CA            M  fully remote
# 4           100               CA            M  fully remote

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder,OrdinalEncoder,MinMaxScaler,StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline,make_pipeline

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
transformer = ColumnTransformer(transformers=[
('OrdinalEncoder_',OrdinalEncoder(categories=[['EN','MI','SE','EX']]),['experience_level']),
('OneHotEncoder_',OneHotEncoder(sparse_output=False,drop='first'),['employment_type','job_title','company_location','company_size','work_type'])
],remainder='passthrough')

# %%
col_name=data.keys()
col_name
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary_in_usd', 'remote_ratio', 'company_location', 'company_size',
#        'work_type'],
#       dtype='object')

# %%
#scaler_=ColumnTransformer(['Scaler',MinMaxScaler(),slice(0,8)])

# %%
pipe= Pipeline([('transformer',transformer)])

# %%
data_p = pipe.fit_transform(data)

# %%
data_p
# Out:
# array([[2.0000e+00, 0.0000e+00, 1.0000e+00, ..., 2.0230e+03, 8.5847e+04,
#         1.0000e+02],
#        [1.0000e+00, 0.0000e+00, 0.0000e+00, ..., 2.0230e+03, 3.0000e+04,
#         1.0000e+02],
#        [1.0000e+00, 0.0000e+00, 0.0000e+00, ..., 2.0230e+03, 2.5500e+04,
#         1.0000e+02],
#        ...,
#        [0.0000e+00, 0.0000e+00, 1.0000e+00, ..., 2.0200e+03, 1.0500e+05,
#         1.0000e+02],
#        [0.0000e+00, 0.0000e+00, 0.0000e+00, ..., 2.0200e+03, 1.0000e+05,
#         1.0000e+02],
#        [2.0000e+00, 0.0000e+00, 1.0000e+00, ..., 2.0210e+03, 9.4665e+04,
#         5.0000e+01]])
